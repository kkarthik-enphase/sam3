# %%
from sam3.model.sam3_image import Sam3ImagePredictor
from PIL import Image
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from sam3.model.sam3_image import Sam3ImagePredictor
#       2 from PIL import Image
#       3 import numpy as np
#
# File ~/ARD/sam3/sam3/model/sam3_image.py:12
#       8 import torch
#      10 from sam3.model.model_misc import SAM3Output
# ---> 12 from sam3.model.sam1_task_predictor import SAM3InteractiveImagePredictor
#      13 from sam3.model.vl_combiner import SAM3VLBackbone
#      14 from sam3.perflib.nms import nms_masks
#
# File ~/ARD/sam3/sam3/model/sam1_task_predictor.py:17
#      14 import torch.nn as nn
#      15 from PIL.Image import Image
# ---> 17 from sam3.model.sam3_tracker_base import Sam3TrackerBase
#      18 from sam3.model.utils.sam1_utils import SAM2Transforms
#      21 # Adapted from https://github.com/facebookresearch/sam2/blob/main/sam2/sam2_image_predictor.py
#
# ...

# %%
pip install einops iopath huggingface_hub opencv-python Pillow matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 16.1 MB/s  0:00:04 eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 10.7 MB/s  0:00:01 10.9 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 7.3 MB/s  0:00:017.8 MB/s eta 0:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 10.6 MB/s  0:00:000.5 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 15.4 MB/s  0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.0
#     Uninstalling numpy-1.26.0:
#       Successfully uninstalled numpy-1.26.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [matplotlib]37m━━━━ 8/9 [matplotlib]on]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sam3 0.1.0 requires numpy==1.26, but you have numpy 2.2.6 which is incompatible.
# ...
